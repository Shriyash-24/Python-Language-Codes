# %% [markdown]
# ## ANOVA

# %% [markdown]
# - Analysis Of Variance
# - Statistical Comparison Of Groups
# - Finding the correlation between groups.
# - Main parameters - F-Test Score - Ratio of variation between groups mean over the variation within the same groups.
# - P - Value - Checks for the significance.
