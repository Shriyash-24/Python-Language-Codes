# %%
import pandas as pd
path = "C:/Users/Shri/Coding/Additional-Files/auto_mpg.csv"
df = pd.read_csv(path)
print(df)
# Out:
#                                               Variable       Breakdown  \
# 0                             _01_Total_RD_Expenditure  ANZSIC_1_Digit
# 1                             _01_Total_RD_Expenditure  ANZSIC_1_Digit
# 2                             _01_Total_RD_Expenditure  ANZSIC_1_Digit
# 3                             _01_Total_RD_Expenditure  ANZSIC_1_Digit
# 4                             _01_Total_RD_Expenditure  ANZSIC_1_Digit
# ...                                                ...             ...
# 48866  _95_Total_RD_Expenditure_as_a_proportion_of_GDP         Country
# 48867  _95_Total_RD_Expenditure_as_a_proportion_of_GDP         Country
# 48868  _95_Total_RD_Expenditure_as_a_proportion_of_GDP         Country
# 48869  _95_Total_RD_Expenditure_as_a_proportion_of_GDP         Country
# 48870  _95_Total_RD_Expenditure_as_a_proportion_of_GDP         Country
#
#                         Breakdown_category  Year RD_Value Status  \
# ...

# %% [markdown]
# #### - head is used to view the starting rows of the file

# %%
df.head(5)
# Out:
#                    Variable       Breakdown  \
# 0  _01_Total_RD_Expenditure  ANZSIC_1_Digit
# 1  _01_Total_RD_Expenditure  ANZSIC_1_Digit
# 2  _01_Total_RD_Expenditure  ANZSIC_1_Digit
# 3  _01_Total_RD_Expenditure  ANZSIC_1_Digit
# 4  _01_Total_RD_Expenditure  ANZSIC_1_Digit
#
#                     Breakdown_category  Year RD_Value Status  \
# 0  A_Agriculture, Forestry and Fishing  2016       91    NaN
# 1  A_Agriculture, Forestry and Fishing  2018       89    NaN
# 2  A_Agriculture, Forestry and Fishing  2019      ...    NaN
# 3  A_Agriculture, Forestry and Fishing  2020       99    NaN
# 4  A_Agriculture, Forestry and Fishing  2021      ...    NaN
#
#                     Unit Footnotes Relative_Sampling_Error
# 0  NZ Dollars (millions)        12                    23.8
# 1  NZ Dollars (millions)        12                    51.7
# 2  NZ Dollars (millions)        12                     ...
# 3  NZ Dollars (millions)        12                    30.2
# ...

# %% [markdown]
# #### - tail is used for last 5 rounds.

# %%
df.tail(5)
# Out:
#                                               Variable Breakdown  \
# 48866  _95_Total_RD_Expenditure_as_a_proportion_of_GDP   Country
# 48867  _95_Total_RD_Expenditure_as_a_proportion_of_GDP   Country
# 48868  _95_Total_RD_Expenditure_as_a_proportion_of_GDP   Country
# 48869  _95_Total_RD_Expenditure_as_a_proportion_of_GDP   Country
# 48870  _95_Total_RD_Expenditure_as_a_proportion_of_GDP   Country
#
#       Breakdown_category  Year RD_Value Status               Unit  Footnotes  \
# 48866      United States  2019     3.14    NaN  Percentage of GDP  33 and 34
# 48867      United States  2020     3.42    NaN  Percentage of GDP  33 and 34
# 48868      United States  2021     3.47    NaN  Percentage of GDP  33 and 34
# 48869      United States  2022     3.49    NaN  Percentage of GDP  33 and 34
# 48870      United States  2023     3.45    NaN  Percentage of GDP  33 and 34
#
#       Relative_Sampling_Error
# 48866                      ..
# 48867                      ..
# ...

# %%
df.to_csv(path) # Save file

# %%
df.dtypes
# Out:
# Variable                   object
# Breakdown                  object
# Breakdown_category         object
# Year                        int64
# RD_Value                   object
# Status                     object
# Unit                       object
# Footnotes                  object
# Relative_Sampling_Error    object
# dtype: object

# %% [markdown]
# #### Object represent number in strings, int64 for integers.

# %%
df.describe() # Helps us to get a statistical summary.
# Out:
#                Year
# count  48871.000000
# mean    2020.345460
# std        2.496032
# min     2016.000000
# 25%     2018.000000
# 50%     2020.000000
# 75%     2022.000000
# max     2024.000000

# %%
df.describe(include="all") # Full summary statistics.
# Out:
#                                                  Variable       Breakdown  \
# count                                               48871           48871
# unique                                                130               7
# top     _94_Higher_Education_Sector_RD_Expenditure_as_...  ANZSIC_1_Digit
# freq                                                  377           16128
# mean                                                  NaN             NaN
# std                                                   NaN             NaN
# min                                                   NaN             NaN
# 25%                                                   NaN             NaN
# 50%                                                   NaN             NaN
# 75%                                                   NaN             NaN
# max                                                   NaN             NaN
#
#                          Breakdown_category          Year RD_Value Status  \
# ...

# %% [markdown]
# ### count is no. of content. Unique is number of distinct objects in column, NaN is not a number.
